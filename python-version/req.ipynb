# %%
pip install numpy scipy sounddevice matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.7 MB 6.7 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/12.7 MB 6.9 MB/s eta 0:00:02
#    --------- ------------------------------ 3.1/12.7 MB 6.0 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.7 MB 5.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.7 MB 5.4 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/12.7 MB 5.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.3/12.7 MB 5.4 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.7 MB 5.4 MB/s eta 0:00:01
# ...

# %%
pip install librosa soundfile
# Out:
# ...
#   Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata (16 kB)
# ...
#   Using cached audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl (1.0 MB)
# Using cached audioread-3.0.1-py3-none-any.whl (23 kB)
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------------------ --------------------- 1.3/2.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 2.6/2.8 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 6.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    - -------------------------------------- 1.3/30.3 MB 6.7 MB/s eta 0:00:05
#    --- ------------------------------------ 2.6/30.3 MB 6.9 MB/s eta 0:00:05
# ...

# %%
pip install numpy==2.2
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.6 MB 6.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.8/12.6 MB 4.4 MB/s eta 0:00:03
#    -------- ------------------------------- 2.6/12.6 MB 4.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/12.6 MB 4.2 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.6 MB 4.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.6 MB 4.5 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/12.6 MB 4.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.6 MB 4.2 MB/s eta 0:00:02
#    ------------------------ --------------- 7.6/12.6 MB 4.1 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.6 MB 4.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.6 MB 4.2 MB/s eta 0:00:01
# ...
